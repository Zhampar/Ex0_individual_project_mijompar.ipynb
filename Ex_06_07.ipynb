# %% [markdown]
# <a href="https://colab.research.google.com/github/Zhampar/Ex0_individual_project_mijompar.ipynb/blob/mijompar.ipynp/Ex_06_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def divide(a, b):
    result = a / b
    return result

def is_prime(n):
    if n <= 1:  # 0 and 1 are not prime numbers
        return False
    for i in range(2, int(n ** 0.5) + 1):  # check up to square root of n
        if n % i == 0:  # divisible by i → not prime
            return False
    return True

# Example: check if 15 is prime
print(is_prime(15))  # Output: False
# Out:
# False

# %%
# Q2.1
a = 1
try:
    b = int(input("Please enter a number to divide a: "))
    a = a / b
    print("Success a= ", a)
except ValueError:
    print("Error: You must enter a valid integer.")
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except Exception as e:
    print("Unexpected error:", e)


# Q2.2
mylist = [2, 3, 5, -7, 8, 0]
idx = 0
b = 5

while idx <= 6:
    try:
        print('Iteration:', idx, mylist[idx] / b)
    except IndexError:
        print(f"Error: Index {idx} is out of range.")
    except ZeroDivisionError:
        print("Error: Division by zero.")
    except Exception as e:
        print("Unexpected error:", e)
    finally:
        idx += 1
        print('Iteration completed')

# %%
# Q2.2
mylist = [2, 3, 5, -7, 8, 0]
idx = 0
b = 5

while idx <= 6:
    try:
        print('Iteration:', idx, mylist[idx] / b)
    except IndexError:
        print(f"Error: Index {idx} is out of range.")
    except ZeroDivisionError:
        print("Error: Division by zero.")
    except Exception as e:
        print("Unexpected error:", e)
    finally:
        idx += 1
        print('Iteration completed')
